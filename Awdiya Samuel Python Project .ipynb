# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('ready')
# Out:
# ready

# %%
sns?
# Out:
# Type:        module
# String form: <module 'seaborn' from 'C:\\Anaconda\\lib\\site-packages\\seaborn\\__init__.py'>
# File:        c:\anaconda\lib\site-packages\seaborn\__init__.py
# Docstring:   <no docstring>

# %%
data = './dataset/africa_food_prices.csv'

# %%
url = pd.read_csv(data, header = 0)

url.head()
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
# 3       15430         4.0  Algeria       344  Alger       1794  Algiers
# 4       15431         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type  \
# 0          52  Rice - Retail          0.0      DZD     15      Retail
# 1          52  Rice - Retail          0.0      DZD     15      Retail
# 2          52  Rice - Retail          0.0      DZD     15      Retail
# 3          52  Rice - Retail          0.0      DZD     15      Retail
# 4          52  Rice - Retail          0.0      DZD     15      Retail
#
#    um_unit_id quantity  month  year  price  mp_commoditysource
# ...

# %%
url.tail()
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency  \
# 956774  Mbilashaba         432   Beans (sugar) - Retail          0.0      ZWL
# 956775  Mbilashaba         539      Toothpaste - Retail          0.0      ZWL
# 956776  Mbilashaba         540    Laundry soap - Retail          0.0      ZWL
# 956777  Mbilashaba         541   Handwash soap - Retail          0.0      ZWL
# 956778  Mbilashaba         887  Fish (kapenta) - Retail          0.0      ZWL
#
# ...

# %%
df= url.copy() #deep copy

df.head(4)
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
# 3       15430         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type  \
# 0          52  Rice - Retail          0.0      DZD     15      Retail
# 1          52  Rice - Retail          0.0      DZD     15      Retail
# 2          52  Rice - Retail          0.0      DZD     15      Retail
# 3          52  Rice - Retail          0.0      DZD     15      Retail
#
#    um_unit_id quantity  month  year  price  mp_commoditysource
# 0           5       KG      4  2015   90.0                 NaN
# 1           5       KG      5  2015   96.0                 NaN
# 2           5       KG      6  2015   96.0                 NaN
# ...

# %%
df
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 0            15427         4.0   Algeria       344     Alger       1794
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency  \
# ...

# %%
df.shape #to get the shape
# Out:
# (956779, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          956779 non-null  int64
#  1   country_id          956779 non-null  float64
#  2   country             956779 non-null  object
#  3   state_id            956779 non-null  int64
#  4   state               830101 non-null  object
#  5   market_id           956779 non-null  int64
#  6   market              956779 non-null  object
#  7   produce_id          956779 non-null  int64
#  8   produce             956779 non-null  object
#  9   currency_id         956779 non-null  float64
#  10  currency            956779 non-null  object
#  11  pt_id               956779 non-null  int64
#  12  market_type         956779 non-null  object
#  13  um_unit_id          956779 non-null  int64
#  14  quantity            956779 non-null  object
# ...

# %%
df.columns #to get the column name
# Out:
# Index(['Unnamed: 0', 'country_id', 'country', 'state_id', 'state', 'market_id',
#        'market', 'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
#        'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price',
#        'mp_commoditysource'],
#       dtype='object')

# %%
cols_to_drop = ['country_id', 'state_id','market_id','produce_id','currency_id','pt_id','um_unit_id','mp_commoditysource'] #i dropped the id
df= df.drop(columns = cols_to_drop, axis = 1)

# %%
df
# Out:
#         Unnamed: 0   country     state      market                  produce  \
# 0            15427   Algeria     Alger     Algiers            Rice - Retail
# 1            15428   Algeria     Alger     Algiers            Rice - Retail
# 2            15429   Algeria     Alger     Algiers            Rice - Retail
# 3            15430   Algeria     Alger     Algiers            Rice - Retail
# 4            15431   Algeria     Alger     Algiers            Rice - Retail
# ...            ...       ...       ...         ...                      ...
# 956774     2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar) - Retail
# 956775     2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste - Retail
# 956776     2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap - Retail
# 956777     2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap - Retail
# 956778     2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta) - Retail
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   956779 non-null  int64
#  1   country      956779 non-null  object
#  2   state        830101 non-null  object
#  3   market       956779 non-null  object
#  4   produce      956779 non-null  object
#  5   currency     956779 non-null  object
#  6   market_type  956779 non-null  object
#  7   quantity     956779 non-null  object
#  8   month        956779 non-null  int64
#  9   year         956779 non-null  int64
#  10  price        956779 non-null  float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 80.3+ MB

# %%
df.shape
# Out:
# (956779, 11)

# %%
#rename the columns
#dataframe rename method
df = df.rename(columns={
    df.columns[0]: 'S/N',
    df.columns[1]: 'country',
    df.columns[2]: 'state',
    df.columns[3]: 'market name',
    df.columns[4]: 'product name',
    'currency' : 'currency name',
    
    
})

# %%
df
# Out:
#             S/N   country     state market name             product name  \
# 0         15427   Algeria     Alger     Algiers            Rice - Retail
# 1         15428   Algeria     Alger     Algiers            Rice - Retail
# 2         15429   Algeria     Alger     Algiers            Rice - Retail
# 3         15430   Algeria     Alger     Algiers            Rice - Retail
# 4         15431   Algeria     Alger     Algiers            Rice - Retail
# ...         ...       ...       ...         ...                      ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar) - Retail
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste - Retail
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap - Retail
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap - Retail
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta) - Retail
#
#        currency name market_type quantity  month  year      price
# ...

# %%
df.columns
# Out:
# Index(['S/N', 'country', 'state', 'market name', 'product name',
#        'currency name', 'market_type', 'quantity', 'month', 'year', 'price'],
#       dtype='object')

# %%
df['product name']
# Out:
# 0                   Rice - Retail
# 1                   Rice - Retail
# 2                   Rice - Retail
# 3                   Rice - Retail
# 4                   Rice - Retail
#                    ...
# 956774     Beans (sugar) - Retail
# 956775        Toothpaste - Retail
# 956776      Laundry soap - Retail
# 956777     Handwash soap - Retail
# 956778    Fish (kapenta) - Retail
# Name: product name, Length: 956779, dtype: object

# %%
#clean the country 
#split text at deliemeters

# %%
print(type(df['product name'][0]))
# Out:
# <class 'str'>

# %%
print(df['product name'][0])
# Out:
# Rice - Retail

# %%
#split on left most parenthesis as the deliemeter
temp = df[ 'product name'].str.split("-", n=1, expand = True)

# %%
temp
# Out:
#                       0        1
# 0                 Rice    Retail
# 1                 Rice    Retail
# 2                 Rice    Retail
# 3                 Rice    Retail
# 4                 Rice    Retail
# ...                 ...      ...
# 956774   Beans (sugar)    Retail
# 956775      Toothpaste    Retail
# 956776    Laundry soap    Retail
# 956777   Handwash soap    Retail
# 956778  Fish (kapenta)    Retail
#
# [956779 rows x 2 columns]

# %%
#replce the product name column in df with the temp [0]

# %%
df['product name'] = temp [0]

# %%
df.head(3)
# Out:
#      S/N  country  state market name product name currency name market_type  \
# 0  15427  Algeria  Alger     Algiers        Rice            DZD      Retail
# 1  15428  Algeria  Alger     Algiers        Rice            DZD      Retail
# 2  15429  Algeria  Alger     Algiers        Rice            DZD      Retail
#
#   quantity  month  year  price
# 0       KG      4  2015   90.0
# 1       KG      5  2015   96.0
# 2       KG      6  2015   96.0

# %%
df.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method='pad')
# Out:
#             S/N   country     state market name     product name  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        currency name market_type quantity  month  year      price
# 0                DZD      Retail       KG      4  2015    90.0000
# ...

# %%
df['quantity'] = df['quantity'].replace('100 ML','ML')

print(df)
# Out:
#             S/N   country     state market name     product name  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        currency name market_type quantity  month  year      price
# 0                DZD      Retail       KG      4  2015    90.0000
# ...

# %%
df
# Out:
#             S/N   country     state market name     product name  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        currency name market_type quantity  month  year      price
# 0                DZD      Retail       KG      4  2015    90.0000
# ...

# %%
df['quantity'] = df['quantity'].replace('250 G','G')

print(df)
# Out:
#             S/N   country     state market name     product name  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        currency name market_type quantity  month  year      price
# 0                DZD      Retail       KG      4  2015    90.0000
# ...

# %%
df
# Out:
#             S/N   country     state market name     product name  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        currency name market_type quantity  month  year      price
# 0                DZD      Retail       KG      4  2015    90.0000
# ...

# %%
# Replace multiple columns values
df['quantity'] = df['quantity'].replace(['900 G', '3 KG', '3.5 KG', 'Unit', 'pcs', '500 G', '125 G', '30 pcs', 'Pounds', '50 Pounds'],['G', ' KG', ' KG', ' L', ' pcs', 'G',' G', ' pcs', 'G', ' G'])

print(df)
# Out:
#             S/N   country     state market name     product name  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        currency name market_type quantity  month  year      price
# 0                DZD      Retail       KG      4  2015    90.0000
# ...

# %%
df
# Out:
#             S/N   country     state market name     product name  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        currency name market_type quantity  month  year      price
# 0                DZD      Retail       KG      4  2015    90.0000
# ...

# %%
df['quantity'] = df['quantity'].replace(['Bunch', '3.5 KG', '50 KG', 'Gallon', 'Loaf', '12.5 KG', '750 ML', '2.25 KG', 'USD/LCU', '200 ML' ], [' G', ' KG', ' KG', ' G', ' L', 'KG', ' ML', ' KG', 'USD', 'ML'])

print(df)
# Out:
#             S/N   country     state market name     product name  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        currency name market_type quantity  month  year      price
# 0                DZD      Retail       KG      4  2015    90.0000
# ...

# %%
df
# Out:
#             S/N   country     state market name     product name  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        currency name market_type quantity  month  year      price
# 0                DZD      Retail       KG      4  2015    90.0000
# ...

# %%
df['quantity'] = df['quantity'].replace(['200 G', '400 G', '250 G', 'Brush', '2.1 KG', '1.5 KG', '1.3 KG', '100 KG', '1.4 KG', 'SACK', '3.5 KG'],[ 'G', 'G', 'G', 'KG', 'KG', 'KG', 'KG', 'KG', 'KG', 'G', 'KG'])

print(df)
# Out:
#             S/N   country     state market name     product name  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        currency name market_type quantity  month  year      price
# 0                DZD      Retail       KG      4  2015    90.0000
# ...

# %%
df
# Out:
#             S/N   country     state market name     product name  \
# 0         15427   Algeria     Alger     Algiers            Rice
# 1         15428   Algeria     Alger     Algiers            Rice
# 2         15429   Algeria     Alger     Algiers            Rice
# 3         15430   Algeria     Alger     Algiers            Rice
# 4         15431   Algeria     Alger     Algiers            Rice
# ...         ...       ...       ...         ...              ...
# 956774  2050633  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)
# 956775  2050634  Zimbabwe  Midlands  Mbilashaba      Toothpaste
# 956776  2050635  Zimbabwe  Midlands  Mbilashaba    Laundry soap
# 956777  2050636  Zimbabwe  Midlands  Mbilashaba   Handwash soap
# 956778  2050637  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)
#
#        currency name market_type quantity  month  year      price
# 0                DZD      Retail       KG      4  2015    90.0000
# ...

# %%
df.to_csv("./africa_food_prices_cleaned.csv",index = False)

# %%
africa_food = pd.read_csv('./africa_food_prices_cleaned.csv')

# %%
africa_food.head()
# Out:
#      S/N  country  state market name product name currency name market_type  \
# 0  15427  Algeria  Alger     Algiers        Rice            DZD      Retail
# 1  15428  Algeria  Alger     Algiers        Rice            DZD      Retail
# 2  15429  Algeria  Alger     Algiers        Rice            DZD      Retail
# 3  15430  Algeria  Alger     Algiers        Rice            DZD      Retail
# 4  15431  Algeria  Alger     Algiers        Rice            DZD      Retail
#
#   quantity  month  year  price
# 0       KG      4  2015   90.0
# 1       KG      5  2015   96.0
# 2       KG      6  2015   96.0
# 3       KG      7  2015   83.0
# 4       KG      8  2015   80.0

# %%
print(type(africa_food['country'][0]))
# Out:
# <class 'str'>

# %%
print(africa_food['country'][0])
# Out:
# Algeria

# %%
africa_food.shape
# Out:
# (956779, 11)

# %%
print("No of rows: ",africa_food.shape[0])
print("No of cols: ",africa_food.shape[1])
# Out:
# No of rows:  956779
# No of cols:  11

# %%
#Check for empty rows /null value

df.isnull().sum()
# Out:
# S/N                   0
# country               0
# state            126678
# market name           0
# product name          0
# currency name         0
# market_type           0
# quantity              0
# month                 0
# year                  0
# price                 0
# dtype: int64

# %%
df = df.dropna(subset = ['state'])

# %%
df.isnull().sum()
# Out:
# S/N              0
# country          0
# state            0
# market name      0
# product name     0
# currency name    0
# market_type      0
# quantity         0
# month            0
# year             0
# price            0
# dtype: int64

# %%
df.describe()
# Out:
#                 S/N          month           year         price
# count  8.301010e+05  830101.000000  830101.000000  8.301010e+05
# mean   1.076686e+06       6.391578    2015.540816  4.538529e+03
# std    5.344933e+05       3.418432       4.626066  1.483042e+05
# min    1.542700e+04       1.000000    1990.000000  0.000000e+00
# 25%    5.834490e+05       3.000000    2013.000000  1.250000e+02
# 50%    1.112122e+06       6.000000    2016.000000  3.000000e+02
# 75%    1.522966e+06       9.000000    2020.000000  8.500000e+02
# max    2.050637e+06      12.000000    2021.000000  1.725000e+07

# %% [markdown]
# # I fitered out Nigeria then i carried out the pivot table.

# %%
africa_food.country = africa_food.country.str.strip()

# %%
country_list = ['Nigeria']
africa_food[africa_food.country.isin(country_list)]
# Out:
#             S/N  country    state   market name           product name  \
# 605293  1301729  Nigeria  Adamawa          Mubi                 Bread
# 605294  1301730  Nigeria  Adamawa          Mubi                 Bread
# 605295  1301731  Nigeria  Adamawa          Mubi                 Bread
# 605296  1301732  Nigeria  Adamawa          Mubi                 Bread
# 605297  1301733  Nigeria  Adamawa          Mubi                 Bread
# ...         ...      ...      ...           ...                    ...
# 655573  1352009  Nigeria  Zamfara  Kaura Namoda  Rice (milled, local)
# 655574  1352010  Nigeria  Zamfara  Kaura Namoda  Rice (milled, local)
# 655575  1352011  Nigeria  Zamfara  Kaura Namoda  Rice (milled, local)
# 655576  1352012  Nigeria  Zamfara  Kaura Namoda  Rice (milled, local)
# 655577  1352013  Nigeria  Zamfara  Kaura Namoda  Rice (milled, local)
#
#        currency name market_type quantity  month  year    price
# ...

# %%
africa_food.columns
# Out:
# Index(['S/N', 'country', 'state', 'market name', 'product name',
#        'currency name', 'market_type', 'quantity', 'month', 'year', 'price'],
#       dtype='object')

# %%
africa_food['market_type'].unique()
# Out:
# array(['Retail', 'Wholesale', 'Producer'], dtype=object)

# %%
africa_food.market_type.value_counts()
# Out:
# Retail       885918
# Wholesale     70613
# Producer        248
# Name: market_type, dtype: int64

# %%
pd.pivot_table(africa_food, index = "market_type")
# Out:
#                       S/N     month        price         year
# market_type
# Producer     1.023454e+06  6.459677   666.338710  2011.471774
# Retail       1.089439e+06  6.380527  3767.706512  2015.788430
# Wholesale    9.122452e+05  6.393030  8671.729344  2014.659808

# %%
africa_food.groupby("market_type")["product name"].first()
# Out:
# market_type
# Producer     Rice (paddy)
# Retail               Rice
# Wholesale           Maize
# Name: product name, dtype: object

# %%
pd.pivot_table(africa_food, index = "market_type")
# Out:
#                       S/N     month        price         year
# market_type
# Producer     1.023454e+06  6.459677   666.338710  2011.471774
# Retail       1.089439e+06  6.380527  3767.706512  2015.788430
# Wholesale    9.122452e+05  6.393030  8671.729344  2014.659808

# %%
#multiple  indicies
#the default aggegaion is the Average
df= pd.pivot_table(df, index = ["state", "market_type"], values = "product name",aggfunc=["sum","count"])

# %%
df
# Out:
#                                                                       sum  \
#                                                              product name
# state      market_type
# Abia       Retail       Bread Bread Bread Bread Bread Bread Bread Brea...
#            Wholesale    Oil (palm) Oil (palm) Oil (palm) Oil (palm) Oi...
# Abim       Retail       Beans Beans Beans Beans Beans Beans Beans Bean...
# Adamaoua   Retail       Maize Maize Maize Maize Maize Oil (palm) Oil (...
#            Wholesale    Maize Maize Maize Maize Maize Maize Maize Maiz...
# ...                                                                   ...
# Zamfara    Wholesale    Oil (palm) Oil (palm) Oil (palm) Oil (palm) Oi...
# Ziguinchor Retail       Maize (local) Maize (local) Maize (local) Maiz...
# Zinder     Retail       Maize Maize Maize Maize Maize Maize Maize Maiz...
#            Wholesale    Rice (imported) Rice (imported) Rice (imported...
# ...

# %%
pd.set_option("display.max_rows", 400)

# %%
df
# Out:
#                                                                                         sum  \
#                                                                                product name
# state                        market_type
# Abia                         Retail       Bread Bread Bread Bread Bread Bread Bread Brea...
#                              Wholesale    Oil (palm) Oil (palm) Oil (palm) Oil (palm) Oi...
# Abim                         Retail       Beans Beans Beans Beans Beans Beans Beans Bean...
# Adamaoua                     Retail       Maize Maize Maize Maize Maize Oil (palm) Oil (...
#                              Wholesale    Maize Maize Maize Maize Maize Maize Maize Maiz...
# Adamawa                      Retail       Bread Bread Bread Bread Bread Bread Bread Brea...
#                              Wholesale    Oil (palm) Oil (palm) Oil (palm) Oil (palm) Oi...
# Addis Ababa                  Retail       Rice Rice Rice Wheat flour Wheat flour Wheat f...
# ...

# %%
africa_food.market_type.value_counts()
# Out:
# Retail       885918
# Wholesale     70613
# Producer        248
# Name: market_type, dtype: int64

# %%
temp = africa_food.market_type.value_counts()
temp.plot(kind='bar')
plt.title("Market Type Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
africa_food.state.value_counts()
# Out:
# North/Amajyaruguru              34770
# South/Amajyepfo                 31610
# East/Iburasirazuba              30805
# West/Iburengerazuba             30032
# Yobe                            15671
# Borno                           14512
# Northern                        13971
# Central River                   13535
# North Bank                      11909
# Kanifing Municipal Council      11548
# Bamako                          11192
# Mopti                           10798
# Kigali City/Umujyi wa Kigali    10529
# Tillaberi                       10244
# Sikasso                          9994
# Segou                            9697
# Southern                         9462
# Zinder                           9144
# Central Region                   9016
# Eastern                          8746
# Southern Region                  8609
# Tombouctou                       8463
# Maradi                           8446
# Koulikoro                        8205
# Tahoua                           8049
# ...

# %%
temp = africa_food.state.value_counts()
temp.plot(kind='bar')
plt.title("State Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
africa_food.sort_values(by=['state']).head(10)
# Out:
#             S/N  country state market name                  product name  \
# 651584  1348020  Nigeria  Abia         Aba  Cassava meal (gari, yellow)
# 651492  1347928  Nigeria  Abia         Aba                Fuel (diesel)
# 651493  1347929  Nigeria  Abia         Aba                Fuel (diesel)
# 651494  1347930  Nigeria  Abia         Aba                Fuel (diesel)
# 651495  1347931  Nigeria  Abia         Aba                Fuel (diesel)
# 651496  1347932  Nigeria  Abia         Aba                Fuel (diesel)
# 651497  1347933  Nigeria  Abia         Aba                Fuel (diesel)
# 651498  1347934  Nigeria  Abia         Aba                Fuel (diesel)
# 651499  1347935  Nigeria  Abia         Aba                Fuel (diesel)
# 651500  1347936  Nigeria  Abia         Aba                Fuel (diesel)
#
#        currency name market_type quantity  month  year   price
# 651584           NGN      Retail       KG      3  2021  385.87
# ...

# %%
africa_food.price.value_counts()
# Out:
# 200.0000     17482
# 500.0000     15850
# 300.0000     14230
# 400.0000     13665
# 250.0000     12945
#              ...
# 120.8500         1
# 97.3675          1
# 90.2300          1
# 83.9050          1
# 1123.3333        1
# Name: price, Length: 108546, dtype: int64

# %%
temp = africa_food.month.value_counts()
temp.plot(kind='barh')
plt.title("Monthly Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
africa_food.groupby('year').price.describe()
# Out:
#          count         mean            std      min        25%        50%  \
# year
# 1990     140.0    98.357143      62.153103  41.0000   53.75000   69.50000
# 1991     134.0   101.854478      53.885175  34.0000   61.25000   80.50000
# 1992     148.0    94.936554      60.162572   1.3400   56.87500   68.50000
# 1993     152.0    87.732039      64.808894   1.0300   50.75000   65.00000
# 1994     843.0   112.857865      71.415062   1.0000   63.00000   86.00000
# 1995     924.0   134.738225     311.907409   1.0300   67.00000   88.00000
# 1996    1045.0   430.808201    1609.128118   1.0300  100.00000  139.00000
# 1997    1065.0  1966.258019   26644.046601   1.0300  136.00000  171.00000
# 1998    1224.0  5552.932034   49609.465469   1.0600  136.00000  209.50000
# 1999    1182.0  2689.108951   30783.483478   1.0500   95.00000  136.00000
# 2000    1319.0  6435.112337   67099.218791   0.5023  101.00000  131.00000
# 2001    1770.0  8926.238971   94332.710528   0.7551   97.00000  161.66520
# ...

# %%
africa_food = africa_food['year'].plot(kind = 'hist')
africa_food.set.xlabel('year')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [69], in <cell line: 2>()
#       1 africa_food = africa_food['year'].plot(kind = 'hist')
# ----> 2 africa_food.set.xlabel('year')
#
# AttributeError: 'function' object has no attribute 'xlabel'

# %%
corelation = df.corr()

# %%
sns.heatmap(corelation ,xticklabels = corelation.columns, yticklabels = corelation.columns
            ,annot=True)
# Out:
# <AxesSubplot:xlabel='None-None', ylabel='None-None'>
